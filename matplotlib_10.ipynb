# %%
import matplotlib.pyplot as plt

# %%
plt.pie([40,30,30])
plt.show()

# %%
plt.pie([40,30,30])
plt.savefig("pie_chart)")
plt.show()

# %%
plt.pie([40,30,30])
plt.savefig("pie_chart_1",dpi=100,quality=99,facecolor="g")
plt.show()
# Out:
# <ipython-input-7-60e3f8ba556d>:2: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig("pie_chart_1",dpi=100,quality=99,facecolor="g")
